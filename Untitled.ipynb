# %%
from sklearn.cluster import DBSCAN
import pickle
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import plotting

# %%
embs = pickle.load(Path('forrest_embs.pkl').open('rb'))
paths = pickle.load(Path('forrest_paths.pkl').open('rb'))
images = pickle.load(Path(
        '/media/neuroscout-data/neuroscout/datasets/raw/studyforrest/stimuli/forrest_cropped_images.pkl').open('rb'))

# %%
clust_07 = DBSCAN(eps=0.7, n_jobs=10).fit(embs)

# %%
clust_08 = DBSCAN(eps=0.8, n_jobs=10).fit(embs)

# %%
len(np.unique(clust_08.labels_))
# Out:
# 53

# %%
plotting.plot_sklearn_clusters(clust_08, images, figsize=(20, 30), n_sample=30)
